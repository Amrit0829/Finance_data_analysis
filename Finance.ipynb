# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv("Finance_data.csv")

# %%
data.head(44)
# Out:
#     gender   age   Income  Monthly_Expenditure  Family_Size_and_Dependents  \
# 0   Female   NaN  55000.0              26000.0                         2.0
# 1   Female  23.0  56000.0              27000.0                         NaN
# 2     Male  30.0  57000.0              28000.0                         4.0
# 3     Male  22.0      NaN              29000.0                         5.0
# 4   Female   NaN  59000.0                  NaN                         6.0
# 5   Female  24.0  60000.0              31000.0                         2.0
# 6   Female  27.0  61000.0              32000.0                         4.0
# 7     Male  21.0  62000.0              33000.0                         3.0
# 8     Male  35.0  63000.0              34000.0                         NaN
# 9     Male  31.0  64000.0              35000.0                         2.0
# 10  Female   NaN  65000.0              36000.0                         NaN
# 11    Male  29.0      NaN              37000.0                         4.0
# 12  Female  21.0  67000.0                  NaN                         5.0
# 13  Female  28.0  68000.0              39000.0                         2.0
# 14  Female  25.0  69000.0              40000.0                         NaN
# 15    Male   NaN  70000.0              41000.0                         3.0
# 16  Female  28.0      NaN              42000.0                         5.0
# 17    Male  27.0  72000.0              43000.0                         2.0
# 18    Male  29.0  73000.0                  NaN                         3.0
# 19    Male   NaN  74000.0              45000.0                         4.0
# 20    Male  29.0  75000.0              46000.0                         NaN
# 21  Female  24.0  76000.0              47000.0                         2.0
# 22    Male  27.0      NaN              48000.0                         4.0
# 23    Male  25.0  78000.0              49000.0                         3.0
# 24  Female  26.0  79000.0                  NaN                         5.0
# 25  Female  32.0  80000.0              51000.0                         2.0
# 26    Male  26.0  81000.0              52000.0                         3.0
# 27    Male   NaN  82000.0              53000.0                         NaN
# 28    Male  29.0  83000.0              54000.0                         5.0
# 29  Female  34.0  84000.0              55000.0                         2.0
# 30    Male  27.0  85000.0              56000.0                         4.0
# 31  Female  31.0      NaN              57000.0                         3.0
# 32    Male  27.0  87000.0              58000.0                         NaN
# 33    Male  26.0  88000.0                  NaN                         2.0
# 34    Male  27.0  89000.0              60000.0                         3.0
# 35    Male   NaN  90000.0              61000.0                         NaN
# 36    Male  30.0  91000.0              62000.0                         5.0
# 37    Male   NaN      NaN              63000.0                         2.0
# 38    Male  31.0  93000.0                  NaN                         4.0
# 39    Male  29.0  94000.0              65000.0                         3.0
#
#    Investment_Avenues Risk_Tolerance_Level  Mutual_Funds  Equity_Market  \
# 0                 Yes                  Low             1              2
# 1                 Yes                  Low             4              3
# 2                 Yes                  Low             3              6
# 3                 Yes                  Low             2              1
# 4                  No               Medium             2              1
# 5                  No               Medium             7              5
# 6                 Yes               Medium             3              6
# 7                 Yes                 High             2              3
# 8                 Yes                 High             2              4
# 9                 Yes                 High             1              3
# 10                Yes                  NaN             2              4
# 11                Yes                  Low             2              5
# 12                 No                  Low             1              2
# 13                Yes               Medium             2              3
# 14                Yes               Medium             2              3
# 15                Yes                  NaN             2              3
# 16                Yes                 High             3              2
# 17                Yes                 High             3              2
# 18                Yes                 High             3              2
# 19                Yes                  Low             3              4
# 20                Yes                  Low             2              4
# 21                Yes                  Low             2              4
# 22                Yes                  NaN             3              4
# 23                Yes               Medium             2              4
# 24                Yes               Medium             2              3
# 25                Yes                  NaN             3              4
# 26                Yes                 High             3              4
# 27                Yes                 High             2              3
# 28                Yes                  Low             2              3
# 29                Yes                  Low             5              4
# 30                Yes                  NaN             4              5
# 31                Yes               Medium             2              4
# 32                Yes               Medium             2              4
# 33                Yes               Medium             2              3
# 34                Yes                 High             2              3
# 35                Yes                  NaN             1              4
# 36                Yes                 High             2              4
# 37                Yes                  Low             5              4
# 38                Yes                  Low             2              4
# 39                Yes                  NaN             4              3
#
#     Debentures  ...           Duration  Invest_Monitor   Expect  \
# 0            5  ...          1-3 years         Monthly  20%-30%
# 1            2  ...  More than 5 years          Weekly  20%-30%
# 2            4  ...          3-5 years           Daily  20%-30%
# 3            3  ...   Less than 1 year           Daily  10%-20%
# 4            3  ...   Less than 1 year           Daily  20%-30%
# 5            4  ...          1-3 years           Daily  30%-40%
# 6            4  ...          3-5 years         Monthly  20%-30%
# 7            7  ...          3-5 years         Monthly  20%-30%
# 8            7  ...          1-3 years          Weekly  20%-30%
# 9            7  ...          3-5 years         Monthly  30%-40%
# 10           7  ...          3-5 years         Monthly  20%-30%
# 11           7  ...          1-3 years         Monthly  20%-30%
# 12           3  ...          1-3 years          Weekly  20%-30%
# 13           7  ...          1-3 years         Monthly  20%-30%
# 14           7  ...          1-3 years         Monthly  20%-30%
# 15           7  ...          1-3 years         Monthly  20%-30%
# 16           7  ...          1-3 years         Monthly  20%-30%
# 17           7  ...          1-3 years         Monthly  20%-30%
# 18           7  ...          1-3 years         Monthly  20%-30%
# 19           6  ...          3-5 years         Monthly  20%-30%
# 20           7  ...          3-5 years          Weekly  20%-30%
# 21           5  ...          3-5 years         Monthly  20%-30%
# 22           6  ...          3-5 years         Monthly  20%-30%
# 23           6  ...          3-5 years          Weekly  20%-30%
# 24           7  ...          3-5 years         Monthly  30%-40%
# 25           7  ...          3-5 years         Monthly  20%-30%
# 26           6  ...          3-5 years         Monthly  20%-30%
# 27           7  ...          1-3 years         Monthly  20%-30%
# 28           6  ...          1-3 years         Monthly  20%-30%
# 29           3  ...          3-5 years         Monthly  10%-20%
# 30           1  ...          1-3 years         Monthly  10%-20%
# 31           7  ...          3-5 years         Monthly  20%-30%
# 32           7  ...          3-5 years         Monthly  30%-40%
# 33           6  ...          1-3 years         Monthly  20%-30%
# 34           6  ...          1-3 years          Weekly  20%-30%
# 35           6  ...          3-5 years         Monthly  20%-30%
# 36           7  ...          1-3 years         Monthly  20%-30%
# 37           7  ...          3-5 years         Monthly  30%-40%
# 38           7  ...          1-3 years          Weekly  20%-30%
# 39           5  ...          3-5 years         Monthly  20%-30%
#
#                    Avenue What are your savings objectives?  \
# 0             Mutual Fund                   Retirement Plan
# 1             Mutual Fund                       Health Care
# 2                  Equity                   Retirement Plan
# 3                  Equity                   Retirement Plan
# 4                  Equity                   Retirement Plan
# 5             Mutual Fund                   Retirement Plan
# 6                  Equity                   Retirement Plan
# 7             Mutual Fund                   Retirement Plan
# 8                  Equity                   Retirement Plan
# 9          Fixed Deposits                   Retirement Plan
# 10            Mutual Fund                   Retirement Plan
# 11            Mutual Fund                   Retirement Plan
# 12            Mutual Fund                         Education
# 13            Mutual Fund                   Retirement Plan
# 14         Fixed Deposits                       Health Care
# 15            Mutual Fund                       Health Care
# 16         Fixed Deposits                       Health Care
# 17            Mutual Fund                   Retirement Plan
# 18            Mutual Fund                   Retirement Plan
# 19         Fixed Deposits                       Health Care
# 20            Mutual Fund                   Retirement Plan
# 21                 Equity                       Health Care
# 22            Mutual Fund                   Retirement Plan
# 23  Public Provident Fund                       Health Care
# 24  Public Provident Fund                   Retirement Plan
# 25            Mutual Fund                   Retirement Plan
# 26            Mutual Fund                   Retirement Plan
# 27         Fixed Deposits                       Health Care
# 28                 Equity                   Retirement Plan
# 29            Mutual Fund                   Retirement Plan
# 30            Mutual Fund                         Education
# 31         Fixed Deposits                   Retirement Plan
# 32                 Equity                       Health Care
# 33         Fixed Deposits                         Education
# 34            Mutual Fund                       Health Care
# 35         Fixed Deposits                       Health Care
# 36                 Equity                   Retirement Plan
# 37  Public Provident Fund                       Health Care
# 38                 Equity                       Health Care
# 39         Fixed Deposits                   Retirement Plan
#
#            Reason_Equity         Reason_Mutual     Reason_Bonds  \
# 0   Capital Appreciation        Better Returns  Safe Investment
# 1               Dividend        Better Returns  Safe Investment
# 2   Capital Appreciation          Tax Benefits  Assured Returns
# 3               Dividend  Fund Diversification   Tax Incentives
# 4   Capital Appreciation        Better Returns  Safe Investment
# 5              Liquidity  Fund Diversification  Safe Investment
# 6   Capital Appreciation        Better Returns  Assured Returns
# 7   Capital Appreciation        Better Returns  Assured Returns
# 8   Capital Appreciation  Fund Diversification  Safe Investment
# 9   Capital Appreciation  Fund Diversification  Assured Returns
# 10  Capital Appreciation        Better Returns  Assured Returns
# 11  Capital Appreciation  Fund Diversification  Assured Returns
# 12              Dividend        Better Returns  Safe Investment
# 13  Capital Appreciation  Fund Diversification  Assured Returns
# 14              Dividend        Better Returns  Assured Returns
# 15  Capital Appreciation  Fund Diversification  Assured Returns
# 16  Capital Appreciation  Fund Diversification  Assured Returns
# 17  Capital Appreciation        Better Returns  Assured Returns
# 18  Capital Appreciation        Better Returns  Assured Returns
# 19  Capital Appreciation  Fund Diversification  Assured Returns
# 20  Capital Appreciation        Better Returns  Assured Returns
# 21  Capital Appreciation        Better Returns  Assured Returns
# 22  Capital Appreciation        Better Returns  Assured Returns
# 23             Liquidity        Better Returns  Assured Returns
# 24  Capital Appreciation        Better Returns  Assured Returns
# 25  Capital Appreciation        Better Returns  Assured Returns
# 26              Dividend  Fund Diversification  Assured Returns
# 27  Capital Appreciation  Fund Diversification  Safe Investment
# 28  Capital Appreciation        Better Returns  Assured Returns
# 29  Capital Appreciation          Tax Benefits  Safe Investment
# 30  Capital Appreciation          Tax Benefits  Safe Investment
# 31  Capital Appreciation        Better Returns  Assured Returns
# 32  Capital Appreciation  Fund Diversification  Assured Returns
# 33              Dividend        Better Returns  Safe Investment
# 34  Capital Appreciation        Better Returns  Safe Investment
# 35  Capital Appreciation        Better Returns  Assured Returns
# 36  Capital Appreciation        Better Returns  Assured Returns
# 37  Capital Appreciation        Better Returns  Safe Investment
# 38              Dividend  Fund Diversification  Assured Returns
# 39              Dividend        Better Returns  Safe Investment
#
#               Reason_FD                    Source
# 0         Fixed Returns  Newspapers and Magazines
# 1   High Interest Rates     Financial Consultants
# 2         Fixed Returns                Television
# 3   High Interest Rates                  Internet
# 4             Risk Free                  Internet
# 5             Risk Free                  Internet
# 6   High Interest Rates     Financial Consultants
# 7             Risk Free  Newspapers and Magazines
# 8         Fixed Returns                Television
# 9         Fixed Returns  Newspapers and Magazines
# 10            Risk Free     Financial Consultants
# 11        Fixed Returns     Financial Consultants
# 12            Risk Free                  Internet
# 13            Risk Free  Newspapers and Magazines
# 14            Risk Free     Financial Consultants
# 15            Risk Free  Newspapers and Magazines
# 16            Risk Free                Television
# 17            Risk Free     Financial Consultants
# 18            Risk Free  Newspapers and Magazines
# 19            Risk Free  Newspapers and Magazines
# 20        Fixed Returns     Financial Consultants
# 21            Risk Free  Newspapers and Magazines
# 22            Risk Free     Financial Consultants
# 23            Risk Free     Financial Consultants
# 24            Risk Free  Newspapers and Magazines
# 25        Fixed Returns     Financial Consultants
# 26        Fixed Returns     Financial Consultants
# 27        Fixed Returns                Television
# 28            Risk Free                Television
# 29        Fixed Returns  Newspapers and Magazines
# 30        Fixed Returns                Television
# 31        Fixed Returns     Financial Consultants
# 32        Fixed Returns  Newspapers and Magazines
# 33            Risk Free  Newspapers and Magazines
# 34        Fixed Returns     Financial Consultants
# 35        Fixed Returns     Financial Consultants
# 36            Risk Free  Newspapers and Magazines
# 37        Fixed Returns     Financial Consultants
# 38        Fixed Returns  Newspapers and Magazines
# 39        Fixed Returns     Financial Consultants
#
# [40 rows x 28 columns]

# %%
# Handle Missing Values
# Check for missing values
print(data.isnull().sum())
# Out:
# gender                               0
# age                                  8
# Income                               6
# Monthly_Expenditure                  6
# Family_Size_and_Dependents           8
# Investment_Avenues                   0
# Risk_Tolerance_Level                 7
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Handle missing values for numerical columns (Age, Income, Monthly_Expenditure, Family_Size_and_Dependents)
numerical_cols = ['age', 'Income', 'Monthly_Expenditure', 'Family_Size_and_Dependents']
imputer = SimpleImputer(strategy='median')  # You can change the strategy to 'mean' or 'most_frequent' as needed
data[numerical_cols] = imputer.fit_transform(data[numerical_cols])

# %%
print(data.isnull().sum())
# Out:
# gender                               0
# age                                  0
# Income                               0
# Monthly_Expenditure                  0
# Family_Size_and_Dependents           0
# Investment_Avenues                   0
# Risk_Tolerance_Level                 7
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
# Handle missing values for categorical column (Risk_Tolerance_Level)
categorical_col = ['Risk_Tolerance_Level']
imputer = SimpleImputer(strategy='most_frequent')  
data[categorical_col] = imputer.fit_transform(data[categorical_col])

# %%
print(data.isnull().sum())
# Out:
# gender                               0
# age                                  0
# Income                               0
# Monthly_Expenditure                  0
# Family_Size_and_Dependents           0
# Investment_Avenues                   0
# Risk_Tolerance_Level                 0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
data.head(4)
# Out:
#    gender   age   Income  Monthly_Expenditure  Family_Size_and_Dependents  \
# 0  Female  27.0  55000.0              26000.0                         2.0
# 1  Female  23.0  56000.0              27000.0                         3.0
# 2    Male  30.0  57000.0              28000.0                         4.0
# 3    Male  22.0  74500.0              29000.0                         5.0
#
#   Investment_Avenues Risk_Tolerance_Level  Mutual_Funds  Equity_Market  \
# 0                Yes                  Low             1              2
# 1                Yes                  Low             4              3
# 2                Yes                  Low             3              6
# 3                Yes                  Low             2              1
#
#    Debentures  ...           Duration  Invest_Monitor   Expect       Avenue  \
# 0           5  ...          1-3 years         Monthly  20%-30%  Mutual Fund
# 1           2  ...  More than 5 years          Weekly  20%-30%  Mutual Fund
# 2           4  ...          3-5 years           Daily  20%-30%       Equity
# 3           3  ...   Less than 1 year           Daily  10%-20%       Equity
#
#   What are your savings objectives?         Reason_Equity  \
# 0                   Retirement Plan  Capital Appreciation
# 1                       Health Care              Dividend
# 2                   Retirement Plan  Capital Appreciation
# 3                   Retirement Plan              Dividend
#
#           Reason_Mutual     Reason_Bonds            Reason_FD  \
# 0        Better Returns  Safe Investment        Fixed Returns
# 1        Better Returns  Safe Investment  High Interest Rates
# 2          Tax Benefits  Assured Returns        Fixed Returns
# 3  Fund Diversification   Tax Incentives  High Interest Rates
#
#                      Source
# 0  Newspapers and Magazines
# 1     Financial Consultants
# 2                Television
# 3                  Internet
#
# [4 rows x 28 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Encode categorical variables
label_encoder = LabelEncoder()
categorical_cols = ['Investment_Avenues', 'Risk_Tolerance_Level', 'Invest_Monitor', 'Expect', 'Avenue']
for col in categorical_cols:
    data[col] = label_encoder.fit_transform(data[col])

# Normalize numerical features
numerical_cols = ['age', 'Income', 'Monthly_Expenditure', 'Family_Size_and_Dependents']
scaler = StandardScaler()
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])

# Display the first few rows of the preprocessed DataFrame
data.head(44)
# Out:
#     gender       age    Income  Monthly_Expenditure  \
# 0   Female -0.133038 -1.825680            -1.813643
# 1   Female -1.463418 -1.731694            -1.719182
# 2     Male  0.864747 -1.637708            -1.624721
# 3     Male -1.796013  0.007049            -1.530261
# 4   Female -0.133038 -1.449735             0.028338
# 5   Female -1.130823 -1.355749            -1.341340
# 6   Female -0.133038 -1.261763            -1.246879
# 7     Male -2.128608 -1.167777            -1.152419
# 8     Male  2.527722 -1.073791            -1.057958
# 9     Male  1.197342 -0.979805            -0.963498
# 10  Female -0.133038 -0.885819            -0.869037
# 11    Male  0.532152  0.007049            -0.774577
# 12  Female -2.128608 -0.697847             0.028338
# 13  Female  0.199557 -0.603861            -0.585655
# 14  Female -0.798228 -0.509875            -0.491195
# 15    Male -0.133038 -0.415888            -0.396734
# 16  Female  0.199557  0.007049            -0.302274
# 17    Male -0.133038 -0.227916            -0.207813
# 18    Male  0.532152 -0.133930             0.028338
# 19    Male -0.133038 -0.039944            -0.018892
# 20    Male  0.532152  0.054042             0.075568
# 21  Female -1.130823  0.148028             0.170029
# 22    Male -0.133038  0.007049             0.264490
# 23    Male -0.798228  0.336000             0.358950
# 24  Female -0.465633  0.429986             0.028338
# 25  Female  1.529937  0.523972             0.547871
# 26    Male -0.465633  0.617959             0.642332
# 27    Male -0.133038  0.711945             0.736792
# 28    Male  0.532152  0.805931             0.831253
# 29  Female  2.195127  0.899917             0.925713
# 30    Male -0.133038  0.993903             1.020174
# 31  Female  1.197342  0.007049             1.114634
# 32    Male -0.133038  1.181875             1.209095
# 33    Male -0.465633  1.275861             0.028338
# 34    Male -0.133038  1.369847             1.398016
# 35    Male -0.133038  1.463833             1.492477
# 36    Male  0.864747  1.557820             1.586937
# 37    Male -0.133038  0.007049             1.681398
# 38    Male  1.197342  1.745792             0.028338
# 39    Male  0.532152  1.839778             1.870319
#
#     Family_Size_and_Dependents  Investment_Avenues  Risk_Tolerance_Level  \
# 0                    -1.207020                   1                     1
# 1                    -0.278543                   1                     1
# 2                     0.649934                   1                     1
# 3                     1.578410                   1                     1
# 4                     2.506887                   0                     2
# 5                    -1.207020                   0                     2
# 6                     0.649934                   1                     2
# 7                    -0.278543                   1                     0
# 8                    -0.278543                   1                     0
# 9                    -1.207020                   1                     0
# 10                   -0.278543                   1                     1
# 11                    0.649934                   1                     1
# 12                    1.578410                   0                     1
# 13                   -1.207020                   1                     2
# 14                   -0.278543                   1                     2
# 15                   -0.278543                   1                     1
# 16                    1.578410                   1                     0
# 17                   -1.207020                   1                     0
# 18                   -0.278543                   1                     0
# 19                    0.649934                   1                     1
# 20                   -0.278543                   1                     1
# 21                   -1.207020                   1                     1
# 22                    0.649934                   1                     1
# 23                   -0.278543                   1                     2
# 24                    1.578410                   1                     2
# 25                   -1.207020                   1                     1
# 26                   -0.278543                   1                     0
# 27                   -0.278543                   1                     0
# 28                    1.578410                   1                     1
# 29                   -1.207020                   1                     1
# 30                    0.649934                   1                     1
# 31                   -0.278543                   1                     2
# 32                   -0.278543                   1                     2
# 33                   -1.207020                   1                     2
# 34                   -0.278543                   1                     0
# 35                   -0.278543                   1                     1
# 36                    1.578410                   1                     0
# 37                   -1.207020                   1                     1
# 38                    0.649934                   1                     1
# 39                   -0.278543                   1                     1
#
#     Mutual_Funds  Equity_Market  Debentures  ...           Duration  \
# 0              1              2           5  ...          1-3 years
# 1              4              3           2  ...  More than 5 years
# 2              3              6           4  ...          3-5 years
# 3              2              1           3  ...   Less than 1 year
# 4              2              1           3  ...   Less than 1 year
# 5              7              5           4  ...          1-3 years
# 6              3              6           4  ...          3-5 years
# 7              2              3           7  ...          3-5 years
# 8              2              4           7  ...          1-3 years
# 9              1              3           7  ...          3-5 years
# 10             2              4           7  ...          3-5 years
# 11             2              5           7  ...          1-3 years
# 12             1              2           3  ...          1-3 years
# 13             2              3           7  ...          1-3 years
# 14             2              3           7  ...          1-3 years
# 15             2              3           7  ...          1-3 years
# 16             3              2           7  ...          1-3 years
# 17             3              2           7  ...          1-3 years
# 18             3              2           7  ...          1-3 years
# 19             3              4           6  ...          3-5 years
# 20             2              4           7  ...          3-5 years
# 21             2              4           5  ...          3-5 years
# 22             3              4           6  ...          3-5 years
# 23             2              4           6  ...          3-5 years
# 24             2              3           7  ...          3-5 years
# 25             3              4           7  ...          3-5 years
# 26             3              4           6  ...          3-5 years
# 27             2              3           7  ...          1-3 years
# 28             2              3           6  ...          1-3 years
# 29             5              4           3  ...          3-5 years
# 30             4              5           1  ...          1-3 years
# 31             2              4           7  ...          3-5 years
# 32             2              4           7  ...          3-5 years
# 33             2              3           6  ...          1-3 years
# 34             2              3           6  ...          1-3 years
# 35             1              4           6  ...          3-5 years
# 36             2              4           7  ...          1-3 years
# 37             5              4           7  ...          3-5 years
# 38             2              4           7  ...          1-3 years
# 39             4              3           5  ...          3-5 years
#
#     Invest_Monitor  Expect  Avenue What are your savings objectives?  \
# 0                1       1       2                   Retirement Plan
# 1                2       1       2                       Health Care
# 2                0       1       0                   Retirement Plan
# 3                0       0       0                   Retirement Plan
# 4                0       1       0                   Retirement Plan
# 5                0       2       2                   Retirement Plan
# 6                1       1       0                   Retirement Plan
# 7                1       1       2                   Retirement Plan
# 8                2       1       0                   Retirement Plan
# 9                1       2       1                   Retirement Plan
# 10               1       1       2                   Retirement Plan
# 11               1       1       2                   Retirement Plan
# 12               2       1       2                         Education
# 13               1       1       2                   Retirement Plan
# 14               1       1       1                       Health Care
# 15               1       1       2                       Health Care
# 16               1       1       1                       Health Care
# 17               1       1       2                   Retirement Plan
# 18               1       1       2                   Retirement Plan
# 19               1       1       1                       Health Care
# 20               2       1       2                   Retirement Plan
# 21               1       1       0                       Health Care
# 22               1       1       2                   Retirement Plan
# 23               2       1       3                       Health Care
# 24               1       2       3                   Retirement Plan
# 25               1       1       2                   Retirement Plan
# 26               1       1       2                   Retirement Plan
# 27               1       1       1                       Health Care
# 28               1       1       0                   Retirement Plan
# 29               1       0       2                   Retirement Plan
# 30               1       0       2                         Education
# 31               1       1       1                   Retirement Plan
# 32               1       2       0                       Health Care
# 33               1       1       1                         Education
# 34               2       1       2                       Health Care
# 35               1       1       1                       Health Care
# 36               1       1       0                   Retirement Plan
# 37               1       2       3                       Health Care
# 38               2       1       0                       Health Care
# 39               1       1       1                   Retirement Plan
#
#            Reason_Equity         Reason_Mutual     Reason_Bonds  \
# 0   Capital Appreciation        Better Returns  Safe Investment
# 1               Dividend        Better Returns  Safe Investment
# 2   Capital Appreciation          Tax Benefits  Assured Returns
# 3               Dividend  Fund Diversification   Tax Incentives
# 4   Capital Appreciation        Better Returns  Safe Investment
# 5              Liquidity  Fund Diversification  Safe Investment
# 6   Capital Appreciation        Better Returns  Assured Returns
# 7   Capital Appreciation        Better Returns  Assured Returns
# 8   Capital Appreciation  Fund Diversification  Safe Investment
# 9   Capital Appreciation  Fund Diversification  Assured Returns
# 10  Capital Appreciation        Better Returns  Assured Returns
# 11  Capital Appreciation  Fund Diversification  Assured Returns
# 12              Dividend        Better Returns  Safe Investment
# 13  Capital Appreciation  Fund Diversification  Assured Returns
# 14              Dividend        Better Returns  Assured Returns
# 15  Capital Appreciation  Fund Diversification  Assured Returns
# 16  Capital Appreciation  Fund Diversification  Assured Returns
# 17  Capital Appreciation        Better Returns  Assured Returns
# 18  Capital Appreciation        Better Returns  Assured Returns
# 19  Capital Appreciation  Fund Diversification  Assured Returns
# 20  Capital Appreciation        Better Returns  Assured Returns
# 21  Capital Appreciation        Better Returns  Assured Returns
# 22  Capital Appreciation        Better Returns  Assured Returns
# 23             Liquidity        Better Returns  Assured Returns
# 24  Capital Appreciation        Better Returns  Assured Returns
# 25  Capital Appreciation        Better Returns  Assured Returns
# 26              Dividend  Fund Diversification  Assured Returns
# 27  Capital Appreciation  Fund Diversification  Safe Investment
# 28  Capital Appreciation        Better Returns  Assured Returns
# 29  Capital Appreciation          Tax Benefits  Safe Investment
# 30  Capital Appreciation          Tax Benefits  Safe Investment
# 31  Capital Appreciation        Better Returns  Assured Returns
# 32  Capital Appreciation  Fund Diversification  Assured Returns
# 33              Dividend        Better Returns  Safe Investment
# 34  Capital Appreciation        Better Returns  Safe Investment
# 35  Capital Appreciation        Better Returns  Assured Returns
# 36  Capital Appreciation        Better Returns  Assured Returns
# 37  Capital Appreciation        Better Returns  Safe Investment
# 38              Dividend  Fund Diversification  Assured Returns
# 39              Dividend        Better Returns  Safe Investment
#
#               Reason_FD                    Source
# 0         Fixed Returns  Newspapers and Magazines
# 1   High Interest Rates     Financial Consultants
# 2         Fixed Returns                Television
# 3   High Interest Rates                  Internet
# 4             Risk Free                  Internet
# 5             Risk Free                  Internet
# 6   High Interest Rates     Financial Consultants
# 7             Risk Free  Newspapers and Magazines
# 8         Fixed Returns                Television
# 9         Fixed Returns  Newspapers and Magazines
# 10            Risk Free     Financial Consultants
# 11        Fixed Returns     Financial Consultants
# 12            Risk Free                  Internet
# 13            Risk Free  Newspapers and Magazines
# 14            Risk Free     Financial Consultants
# 15            Risk Free  Newspapers and Magazines
# 16            Risk Free                Television
# 17            Risk Free     Financial Consultants
# 18            Risk Free  Newspapers and Magazines
# 19            Risk Free  Newspapers and Magazines
# 20        Fixed Returns     Financial Consultants
# 21            Risk Free  Newspapers and Magazines
# 22            Risk Free     Financial Consultants
# 23            Risk Free     Financial Consultants
# 24            Risk Free  Newspapers and Magazines
# 25        Fixed Returns     Financial Consultants
# 26        Fixed Returns     Financial Consultants
# 27        Fixed Returns                Television
# 28            Risk Free                Television
# 29        Fixed Returns  Newspapers and Magazines
# 30        Fixed Returns                Television
# 31        Fixed Returns     Financial Consultants
# 32        Fixed Returns  Newspapers and Magazines
# 33            Risk Free  Newspapers and Magazines
# 34        Fixed Returns     Financial Consultants
# 35        Fixed Returns     Financial Consultants
# 36            Risk Free  Newspapers and Magazines
# 37        Fixed Returns     Financial Consultants
# 38        Fixed Returns  Newspapers and Magazines
# 39        Fixed Returns     Financial Consultants
#
# [40 rows x 28 columns]

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('Finance_data.csv')

# Display the first few rows of the dataset
print(data.head())

# Explore the distribution of numerical variables
numerical_cols = ['age', 'Income', 'Monthly_Expenditure', 'Family_Size_and_Dependents']
data[numerical_cols].hist(figsize=(10, 8), bins=20)
plt.suptitle('Distribution of Numerical Variables', y=1.02)
plt.tight_layout()
plt.show()

# Explore the distribution of categorical variables
categorical_cols = ['gender', 'Investment_Avenues', 'Risk_Tolerance_Level', 'Objective']
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
for i, col in enumerate(categorical_cols):
    sns.countplot(x=col, data=data, ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# Analyze relationships with investment outcomes
investment_cols = ['Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'Fixed_Deposits']
sns.pairplot(data[investment_cols])
plt.suptitle('Relationships with Investment Outcomes', y=1.02)
plt.tight_layout()
plt.show()

# Identify trends and patterns
sns.relplot(x='age', y='Income', hue='Objective', data=data, kind='scatter', aspect=2)
plt.title('Trends: Age vs. Income by Objective')
plt.show()

# Additional analysis and visualization as needed...

# Interpretation and insights
# Summarize key findings and insights based on the analysis
# Out:
#    gender   age   Income  Monthly_Expenditure  Family_Size_and_Dependents  \
# 0  Female   NaN  55000.0              26000.0                         2.0
# 1  Female  23.0  56000.0              27000.0                         NaN
# 2    Male  30.0  57000.0              28000.0                         4.0
# 3    Male  22.0      NaN              29000.0                         5.0
# 4  Female   NaN  59000.0                  NaN                         6.0
#
#   Investment_Avenues Risk_Tolerance_Level  Mutual_Funds  Equity_Market  \
# 0                Yes                  Low             1              2
# 1                Yes                  Low             4              3
# 2                Yes                  Low             3              6
# 3                Yes                  Low             2              1
# 4                 No               Medium             2              1
#
#    Debentures  ...           Duration  Invest_Monitor   Expect       Avenue  \
# 0           5  ...          1-3 years         Monthly  20%-30%  Mutual Fund
# 1           2  ...  More than 5 years          Weekly  20%-30%  Mutual Fund
# 2           4  ...          3-5 years           Daily  20%-30%       Equity
# 3           3  ...   Less than 1 year           Daily  10%-20%       Equity
# 4           3  ...   Less than 1 year           Daily  20%-30%       Equity
#
#   What are your savings objectives?         Reason_Equity  \
# 0                   Retirement Plan  Capital Appreciation
# 1                       Health Care              Dividend
# 2                   Retirement Plan  Capital Appreciation
# 3                   Retirement Plan              Dividend
# 4                   Retirement Plan  Capital Appreciation
#
#           Reason_Mutual     Reason_Bonds            Reason_FD  \
# 0        Better Returns  Safe Investment        Fixed Returns
# 1        Better Returns  Safe Investment  High Interest Rates
# 2          Tax Benefits  Assured Returns        Fixed Returns
# 3  Fund Diversification   Tax Incentives  High Interest Rates
# 4        Better Returns  Safe Investment            Risk Free
#
#                      Source
# 0  Newspapers and Magazines
# 1     Financial Consultants
# 2                Television
# 3                  Internet
# 4                  Internet
#
# [5 rows x 28 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load the dataset
data = pd.read_csv("Finance_data.csv")

# Drop rows with missing values
data = data.dropna()

# Separate features and target variable
X = data.drop(columns=["Investment_Avenues"])
y = data["Investment_Avenues"]

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Encode categorical variables
X_encoded = pd.get_dummies(X)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train different classification models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100)
}

# Train and evaluate models
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Model: {name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))
    print("="*50)
# Out:
# Model: Logistic Regression
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# ==================================================
# Model: Decision Tree
# Accuracy: 0.67
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.33      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
# ==================================================
# Model: Random Forest
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# ==================================================
# C:\Users\AMRIT SHYAM KADBHANE\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\AMRIT SHYAM KADBHANE\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\AMRIT SHYAM KADBHANE\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load the dataset
data = pd.read_csv("Finance_data.csv")

# Drop rows with missing values
data = data.dropna()

# Separate features and target variable
X = data.drop(columns=["Investment_Avenues"])
y = data["Investment_Avenues"]

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Encode categorical variables
X_encoded = pd.get_dummies(X)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train different classification models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100)
}

# Train and evaluate models
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Model: {name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))
    print("="*50)

# Now, let's predict using a sample input data
# Assume input_df contains the input data
input_df_encoded = pd.get_dummies(input_df)

# Reorder the columns of the input data to match the columns of the training data
input_df_encoded = input_df_encoded.reindex(columns=X_encoded.columns, fill_value=0)

# Scale the input features
input_scaled = scaler.transform(input_df_encoded)

# Predict investment options using the trained Random Forest model
predictions = models['Random Forest'].predict(input_scaled)
# Out:
# Model: Logistic Regression
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# ==================================================
# Model: Decision Tree
# Accuracy: 0.67
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.33      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
# ==================================================
# Model: Random Forest
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# ==================================================
# C:\Users\AMRIT SHYAM KADBHANE\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\AMRIT SHYAM KADBHANE\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\AMRIT SHYAM KADBHANE\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Define a function to predict suitable investment types
def predict_investment(input_data):
    # Convert input data to DataFrame
    input_df = pd.DataFrame(input_data, index=[0])
    # Encode categorical variables
    input_df_encoded = pd.get_dummies(input_df, columns=input_df.columns)
    # Align input data with training data to ensure consistent columns
    input_df_encoded = input_df_encoded.reindex(columns=X_encoded.columns, fill_value=0)
    # Scale the input features using the same scaler used for training data
    input_scaled = scaler.transform(input_df_encoded)
    # Predict investment options using the trained Random Forest model
    predictions = random_forest.predict(input_scaled)
    # Decode the predicted labels back to their original values
    predicted_investment_options = label_encoder.inverse_transform(predictions)
    
    # Get the corresponding investment types for each predicted option
    investment_types = []
    for col, value in input_data.items():
        if col in ['Mutual_Funds', 'Equity_Market', 'Debentures', 
                   'Government_Bonds', 'Fixed_Deposits', 'PPF', 
                   'Gold', 'Stock_Market']:
            # Check if the value is numeric
            if str(value[0]).isnumeric():
                # Ensure value is converted to integer before comparison
                if int(value[0]) <= 4:
                    investment_types.append(col)
    
    return predicted_investment_options, [investment_types]

# Example input data
input_data = {
    "gender": ["Male"],
    "age": [31],
    "Income": [64000],
    "Monthly_Expenditure": [35000],
    "Family_Size_and_Dependents": [2],
    "Risk_Tolerance_Level": ["High"],
    "Mutual_Funds": [1],
    "Equity_Market": [3],
    "Debentures": [7],
    "Government_Bonds": [4],
    "Fixed_Deposits": [5],
    "PPF": [2],
    "Gold": [6],
    "Stock_Market": ["Yes"],
    "Factor": ["Returns"],
    "Objective": ["Capital Appreciation"],
    "Purpose": ["Wealth Creation"],
    "Duration": ["3-5 years"],
    "Invest_Monitor": ["Monthly"],
    "Expect": ["30%-40%"],
    "Avenue": ["Fixed Deposits"],
    "What are your savings objectives?": ["Retirement Plan"],
    "Reason_Equity": ["Capital Appreciation"],
    "Reason_Mutual": ["Fund Diversification"],
    "Reason_Bonds": ["Assured Returns"],
    "Reason_FD": ["Fixed Returns"],
    "Source": ["Newspapers and Magazines"]
}

# Predict suitable investment types
predicted_investments, investment_types = predict_investment(input_data)
print("Predicted investment:", predicted_investments)
print("Recommended investment types:", investment_types)
# Out:
# Predicted investment: ['Yes']
# Recommended investment types: [['Mutual_Funds', 'Equity_Market', 'Government_Bonds', 'PPF']]
